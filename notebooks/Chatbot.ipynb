# %%
import pandas as pd

data = pd.read_csv('../data/processed/danh_sach_thong_tin_dia_danh_chi_tiet.csv')
data
# Out:
#                                             TenDiaDanh  \
# 0    Di tích lịch sử - văn hóa căn cứ địa cách mạng...
# 1                                 Chợ Trung tâm Ba Chẽ
# 2                   Di tích lịch sử Miếu Ông – Miếu Bà
# 3                                   Phố đi bộ Tiên Yên
# 4    Trung tâm Văn hóa, Thể thao các dân tộc vùng Đ...
# ..                                                 ...
# 953                    Khu du lịch và sân golf Tam Đảo
# 954                                       Chùa Hà Tiên
# 955                                      Biển Vũng Tàu
# 956                                            Bãi Dứa
# 957                                   Công viên Hồ Tây
#
#                                                 DiaChi  \
# 0    xã Thanh Lâm, Xã Thanh Lâm, Huyện Ba Chẽ, Quản...
# 1    Thị trấn Ba Chẽ, Thị trấn Ba Chẽ, Huyện Ba Chẽ...
# 2     xã Nam Sơn, Xã Nam Sơn, Huyện Ba Chẽ, Quảng Ninh
# 3    Thị trấn Tiên Yên, Thị trấn Tiên Yên, Huyện Ti...
# ...
